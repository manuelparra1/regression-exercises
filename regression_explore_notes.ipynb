# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats

import wrangle
from regprepare import *

# %%
df = get_auto_mpg()

# %%
df.head()
# Out:
#     mpg  cylinders  displ  horsepower  weight   acc  model_year  origin  \
# 0  18.0          8  307.0       130.0  3504.0  12.0          70       1
# 1  15.0          8  350.0       165.0  3693.0  11.5          70       1
# 2  18.0          8  318.0       150.0  3436.0  11.0          70       1
# 3  16.0          8  304.0       150.0  3433.0  12.0          70       1
# 4  17.0          8  302.0       140.0  3449.0  10.5          70       1
#
#                           name
# 0  "chevrolet chevelle malibu"
# 1          "buick skylark 320"
# 2         "plymouth satellite"
# 3              "amc rebel sst"
# 4                "ford torino"

# %% [markdown]
# ## Discrete vs Continuous

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   mpg         392 non-null    float64
#  1   cylinders   392 non-null    int64
#  2   displ       392 non-null    float64
#  3   horsepower  392 non-null    float64
#  4   weight      392 non-null    float64
#  5   acc         392 non-null    float64
#  6   model_year  392 non-null    int64
#  7   origin      392 non-null    int64
#  8   name        392 non-null    object
# dtypes: float64(5), int64(3), object(1)
# memory usage: 30.6+ KB

# %%
train,val,test = train_val_test(df)

# %%
cont_var = ['mpg','displ','horsepower','weight','acc']

# %% [markdown]
# `strongest_correlation = highest(r^2) and lowest(p-value)`

# %%
for col in cont_var:b
    plt.hist(train[col])

# %%
sns.relplot(x='horsepower',y='mpg',data=train)
plt.show()

# %%
sns.lmplot(x='horsepower',y='mpg',data=train,line_kws={'color': '#DD6464'},scatter_kws={'color':'#525252'})
font = {'family': 'Georgia',
            'color':  '#525252',
            'weight': 'bold',
            'size': 25,
            }
plt.title("lmplot",color='#525252', fontdict=font)
plt.ylabel(r"y", fontsize=14, color="#525252", fontdict=font)
plt.xlabel(r"x", fontsize=14, color="#525252", fontdict=font)

plt.show()

# %% [markdown]
# Strong negative correlation between horsepower and mpg.

# %%
sns.swarmplot(x='origin', y='mpg', data=train)
plt.show()

# %% [markdown]
# cat vs num
#
# 1-sample t-test
#
# mpg of origin 1 to mean of dataset

# %% [markdown]
# `strongest_correlation = highest(r^2) and lowest(p-value)`

# %%
stats.ttest_1samp(train[train['origin']==1]['mpg'],train['mpg'].mean())
# Out:
# Ttest_1sampResult(statistic=-6.187826120031006, pvalue=5.335898074820472e-09)
