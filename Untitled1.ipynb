# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from wrangle import *

from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression, LassoLars, TweedieRegressor
from sklearn.preprocessing import PolynomialFeatures

# %%
df = wrangle_zillow()
# Out:
# Reading CSV

# %%
df.head().T
# Out:
#                                                      4   \
# bedroomcnt                                          4.0
# bathroomcnt                                         2.0
# calculatedfinishedsquarefeet                     3633.0
# taxvaluedollarcnt                              296425.0
# yearbuilt                                          2005
# taxamount                                       6941.39
# fips                                              06037
# propertylandusedesc           Single Family Residential
#
#                                                      6   \
# bedroomcnt                                          3.0
# bathroomcnt                                         4.0
# calculatedfinishedsquarefeet                     1620.0
# taxvaluedollarcnt                              847770.0
# yearbuilt                                          2011
# taxamount                                      10244.94
# fips                                              06037
# propertylandusedesc           Single Family Residential
#
#                                                      7   \
# bedroomcnt                                          3.0
# bathroomcnt                                         2.0
# calculatedfinishedsquarefeet                     2077.0
# taxvaluedollarcnt                              646760.0
# yearbuilt                                          1926
# taxamount                                       7924.68
# fips                                              06037
# propertylandusedesc           Single Family Residential
#
#                                                      11  \
# bedroomcnt                                          0.0
# bathroomcnt                                         0.0
# calculatedfinishedsquarefeet                     1200.0
# taxvaluedollarcnt                                5328.0
# yearbuilt                                          1972
# taxamount                                          91.6
# fips                                              06037
# propertylandusedesc           Single Family Residential
#
#                                                      14
# bedroomcnt                                          0.0
# bathroomcnt                                         0.0
# calculatedfinishedsquarefeet                      171.0
# taxvaluedollarcnt                                6920.0
# yearbuilt                                          1973
# taxamount                                        255.17
# fips                                              06037
# propertylandusedesc           Single Family Residential
